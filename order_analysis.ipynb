# %% [markdown]
# # Orders Data Analysis

# %%
# Import libraries
import zipfile
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("error")

# %%
import os
print(os.listdir())
# Out:
# ['-1.14-windows.xml', '.anaconda', '.azuredatastudio', '.bash_history', '.cache', '.cline', '.conda', '.continuum', '.copilot', '.gitconfig', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.kaggle', '.kivy', '.matplotlib', '.micromamba', '.ms-ad', '.ollama', '.spyder-py3', '.th-client', '.thumbnails', '.vscode', '1 Pandas1.ipynb', '1 Stats.ipynb', '10mar25_inferential_stat.ipynb', '2 Programs on conditions and Loops.ipynb', '26-02-25.ipynb', '3D Objects', 'age.c', 'Amazon-Products.csv', 'Amazon_Books.csv', 'anaconda_projects', 'AppData', 'Application Data', 'assignment condition-1.docx', 'assignment_condition1.ipynb', 'Banking.csv', 'Bank_loan.ipynb', 'Blinkit.ipynb', 'blinkit_data.csv', 'Bnking_case.ipynb', 'column_datatype.csv', 'Contacts', 'Cookies', 'customer', 'CUSTOMER SUPPORT DATA ANALYSIS & TICKET RESOLUTION.ipynb', 'customer_shopping_behavior (1).csv', 'customer_shopping_behavior.csv', 'customer_support_tickets.csv', 'data', 'data.csv', 'dataco-supplychaindata.csv
# ...

# %%
with zipfile.ZipFile(r'C:\Users\Sarita Bhuyan\Downloads\archive (25).zip') as zip_ref:
    zip_ref.extractall()

# %%
df = pd.read_csv('orders.csv')
df
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
df.duplicated()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# Order Id            9994
# Order Date           730
# Ship Mode              6
# Segment                3
# Country                1
# City                 531
# State                 49
# Postal Code          631
# Region                 4
# Category               3
# Sub Category          17
# Product Id          1862
# cost price           280
# List Price           289
# Quantity              14
# Discount Percent       4
# dtype: int64

# %%
df.describe()
# Out:
#           Order Id   Postal Code    cost price    List Price     Quantity  \
# count  9994.000000   9994.000000   9994.000000   9994.000000  9994.000000
# mean   4997.500000  55190.379428    201.189714    229.756854     3.789574
# std    2885.163629  32063.693350    537.743203    623.245839     2.225110
# min       1.000000   1040.000000      0.000000      0.000000     1.000000
# 25%    2499.250000  23223.000000     20.000000     20.000000     2.000000
# 50%    4997.500000  56430.500000     50.000000     50.000000     3.000000
# 75%    7495.750000  90008.000000    180.000000    210.000000     5.000000
# max    9994.000000  99301.000000  18110.000000  22640.000000    14.000000
#
#        Discount Percent
# count       9994.000000
# mean           3.484090
# std            1.114211
# min            2.000000
# 25%            2.000000
# 50%            3.000000
# 75%            4.000000
# max            5.000000

# %%
df.isnull().sum()
# Out:
# Order Id            0
# Order Date          0
# Ship Mode           1
# Segment             0
# Country             0
# City                0
# State               0
# Postal Code         0
# Region              0
# Category            0
# Sub Category        0
# Product Id          0
# cost price          0
# List Price          0
# Quantity            0
# Discount Percent    0
# dtype: int64

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'Not Available', 'unknown',
#        'First Class', nan, 'Same Day'], dtype=object)

# %%
df['Ship Mode'] = df['Ship Mode'].replace(['Not Available', 'unknown'], np.nan)

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['Order Id', 'Order Date', 'Ship Mode', 'Segment', 'Country', 'City',
#        'State', 'Postal Code', 'Region', 'Category', 'Sub Category',
#        'Product Id', 'cost price', 'List Price', 'Quantity',
#        'Discount Percent'],
#       dtype='object')

# %%
df.rename(columns={
    'Order Id': 'order_id',
    'Ship Mode': 'ship_mode'
}, inplace=True)
df
# Out:
#       order_id  Order Date       ship_mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
df.columns=df.columns.str.lower()

# %%
df.columns=df.columns.str.replace(' ','__')

# %%
df.head(5)
# Out:
#    order_id order__date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal__code region         category  \
# 0        Henderson    Kentucky         42420  South        Furniture
# 1        Henderson    Kentucky         42420  South        Furniture
# 2      Los Angeles  California         90036   West  Office Supplies
# 3  Fort Lauderdale     Florida         33311  South        Furniture
# 4  Fort Lauderdale     Florida         33311  South  Office Supplies
#
#   sub__category      product__id  cost__price  list__price  quantity  \
# 0     Bookcases  FUR-BO-10001798          240          260         2
# ...

# %%
df['discount']=df['list__price'] * df['discount__percent'] * .01
df
# Out:
#       order_id order__date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal__code region         category  \
# ...

# %%
df['sale_price'] = df['list__price'] - df['discount']
df
# Out:
#       order_id order__date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal__code region         category  \
# ...

# %%
df['profit'] = df['sale_price'] - df['cost__price']
df
# Out:
#       order_id order__date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal__code region         category  \
# ...

# %%
df['order__date'] = pd.to_datetime(df['order__date'],format="%Y-%m-%d")
df
# Out:
#       order_id order__date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal__code region         category  \
# ...

# %%
df.drop(columns=['list_price','cost_price','discount_percent'], inplace=True, errors='ignore')
df
# Out:
#       order_id order__date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal__code region         category  \
# ...

# %%
import mysql.connector
conn = mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="1234",
    database="orders"
)

from sqlalchemy import create_engine
engine = create_engine("mysql+mysqlconnector://root:1234@127.0.0.1/orders")
df.to_sql('orders', con=engine, if_exists='append', index=False)
cursor = conn.cursor()
cursor.execute("SELECT * FROM orders")

for row in cursor.fetchall():
    print(row)
# Out:
# (1, datetime.date(2023, 3, 1), 'Second Class', 'Consumer', 'United States', 'Henderson', 'Kentucky', '42420', 'South', 'Furniture', 'Bookcases', 'FUR-BO-10001798', 2, Decimal('5.20'), Decimal('254.80'), Decimal('14.80'))
# (2, datetime.date(2023, 8, 15), 'Second Class', 'Consumer', 'United States', 'Henderson', 'Kentucky', '42420', 'South', 'Furniture', 'Chairs', 'FUR-CH-10000454', 3, Decimal('21.90'), Decimal('708.10'), Decimal('108.10'))
# (3, datetime.date(2023, 1, 10), 'Second Class', 'Corporate', 'United States', 'Los Angeles', 'California', '90036', 'West', 'Office Supplies', 'Labels', 'OFF-LA-10000240', 2, Decimal('0.50'), Decimal('9.50'), Decimal('-0.50'))
# (4, datetime.date(2022, 6, 18), 'Standard Class', 'Consumer', 'United States', 'Fort Lauderdale', 'Florida', '33311', 'South', 'Furniture', 'Tables', 'FUR-TA-10000577', 5, Decimal('19.20'), Decimal('940.80'), Decimal('160.80'))
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+mysqlconnector://root:1234@127.0.0.1/orders")
